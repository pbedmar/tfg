# %%
# %cd "/mnt/homeGPU1/pbedmar/pycharm/experiments/taming_transformers/taming-transformers/"
# Out:
# /mnt/homeGPU1/pbedmar/pycharm/experiments/taming_transformers/taming-transformers

# %%
import shutil
import os
import random
import numpy as np
import torch
import glob

from functions import sample_perlin_and_clean

np.random.seed(1)
torch.manual_seed(1)
random.seed(1)
# Out:
# /mnt/homeGPU1/pbedmar/pbedmar.tfg.taming.train/lib/python3.8/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729009598/work/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
sample_perlin_and_clean("_fixseed_256_aug2_70/", "70", "2022-06-18T10-44-35", size=256, amp=1, freq=2, cutoff=240, n=50, output_path="../synthetic_dataset/")
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# ...

# %%
sample_perlin_and_clean("_fixseed_256_aug2_70/", "70", "2022-06-18T10-44-35", size=256, amp=1, freq=4, cutoff=240, n=50, output_path="../synthetic_dataset/")
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# ...

# %%
sample_perlin_and_clean("_fixseed_256_aug2_70/", "70", "2022-06-18T10-44-35", size=256, amp=3, freq=2, cutoff=245, n=50, output_path="../synthetic_dataset/")
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# ...

# %%
sample_perlin_and_clean("_fixseed_256_aug2_75/", "75", "2022-06-18T15-30-37", size=256, amp=1, freq=4, cutoff=245, n=50, output_path="../synthetic_dataset/")
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# ...

# %%
sample_perlin_and_clean("_fixseed_256_aug2_75/", "75", "2022-06-18T15-30-37", size=256, amp=3, freq=2, cutoff=245, n=50, output_path="../synthetic_dataset/")
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# ...

# %%
sample_perlin_and_clean("_fixseed_256_aug2_80/", "80", "2022-06-18T20-35-09", size=256, amp=1, freq=2, cutoff=245, n=50, output_path="../synthetic_dataset/")
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# ...

# %%
sample_perlin_and_clean("_fixseed_256_aug2_85/", "85", "2022-06-19T01-48-45", size=256, amp=1, freq=2, cutoff=245, n=50, output_path="../synthetic_dataset/")
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# ...

# %%
sample_perlin_and_clean("_fixseed_256_aug2_85/", "85", "2022-06-19T01-48-45", size=256, amp=7, freq=2, cutoff=320, n=50, output_path="../synthetic_dataset/")
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# Unsqueezed: torch.Size([1, 3, 256, 256])
# VQGAN --- VQModel: latent shape: torch.Size([16, 16])
# ...

# %%
synthetic_path = "../synthetic_dataset/"
dataset_path = "../../../datasets/negev/not_molecules_plus_synthetic/"
filenames = glob.glob(synthetic_path+"*.jpg")
os.makedirs(dataset_path, exist_ok=True)

for i, filename in enumerate(filenames):
    shutil.copy(filename, dataset_path+str(i)+".jpg")

# %%
np.random.seed(1)
torch.manual_seed(1)
random.seed(1)

negative_path = "../../../datasets/negev/not_molecules/preprocess256/"
dataset_path="../../../datasets/negev/not_molecules_plus_synthetic/"
filenames = glob.glob(negative_path+"*.jpg")

n = 400
filenames_sample = random.sample(filenames, n)
for i, filename in enumerate(filenames_sample):
    shutil.copy(filename, dataset_path+str(i+n)+".jpg")
